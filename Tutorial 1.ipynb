# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print(8*3)
# Out:
# 24

# %%
print(8!)
# Out:
#   Input In [3]
#     print(8!)
#            ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1, 20, 40)
y = np.sin(x)
plt.plot(x, y)

# %%
print("This is code you should enter and hit Shift-Return!")
# Out:
# This is code you should enter and hit Shift-Return!

# %%
x = np.linspace(0, 20, 41)
y = np.sin(x)
plt.plot(x, y, 'ro-')

# %%
x = np.linspace(0, 20, 41)
y = np.sin(x)
plt.plot(x, y, 'po-')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 3>()
#       1 x = np.linspace(0, 20, 41)
#       2 y = np.sin(x)
# ----> 3 plt.plot(x, y, 'po-')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:449, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     446 if len(tup) > 1 and isinstance(tup[-1], str):
#     447     # xy is tup with fmt stripped (could still be (y,) only)
#     448     *xy, fmt = tup
# --> 449     linestyle, marker, color = _process_plot_format(fmt)
#     450 elif len(tup) == 3:
#     451     raise ValueError('third arg must be a format string')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:184, in _process_plot_format(fmt)
#     182 elif c in mlines.lineMarkers:
#     183     if marker is not None:
# --> 184         raise ValueError(
#     185             'Illegal format string "%s"; two marker symbols' % fmt)
#     186     marker = c
#     187     i += 1
#
# ValueError: Illegal format string "po-"; two marker symbols

# %%
x = np.linspace(0, 20, 41)
y = np.sin(x)
plt.plot(x, y, 'gs-')

# %%
start, stop, n = 0, 5, 6
x2 = np.linspace(start, stop, n)
print(x2)
# Out:
# [0. 1. 2. 3. 4. 5.]

# %%
start, stop, n = 1, 5, 6
x2 = np.linspace(start, stop, n)
print(x2)
# Out:
# [1.  1.8 2.6 3.4 4.2 5. ]

# %%
y2 = np.sin(x2)
print(y2)
# Out:
# [ 0.84147098  0.97384763  0.51550137 -0.2555411  -0.87157577 -0.95892427]

# %%
start, stop, n = 0, 5, 6
x2 = np.linspace(start, stop, n)
print(x2)
# Out:
# [0. 1. 2. 3. 4. 5.]

# %%
y2 = np.sin(x2)
print(y2)
# Out:
# [ 0.          0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427]

# %%
start, stop, n = 0, 20, 41
x = np.linspace(start, stop, n)
y1 = np.sin(x)
y2 = 0.3*np.random.randn(n) # Gaussian noise from numpy.random (scaled down
plt.plot(x, y1, 'b+:')
plt.plot(x, y2, 'rs-')

# %%
print (n)
# Out:
# 41

# %%
print (x)
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10.  10.5 11.  11.5 12.  12.5 13.  13.5
#  14.  14.5 15.  15.5 16.  16.5 17.  17.5 18.  18.5 19.  19.5 20. ]

# %%
print(x[0:5])
# Out:
# [0.  0.5 1.  1.5 2. ]

# %%
print(x[-5:])
# Out:
# [18.  18.5 19.  19.5 20. ]

# %%
plt.plot(x
        )

# %%
# %who
# Out:
# n	 np	 plt	 start	 stop	 x	 x2	 y	 y1
# y2

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# n          int        41
# np         module     <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# plt        module     <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# start      int        0
# stop       int        20
# x          ndarray    41: 41 elems, type `float64`, 328 bytes
# x2         ndarray    6: 6 elems, type `float64`, 48 bytes
# y          ndarray    41: 41 elems, type `float64`, 328 bytes
# y1         ndarray    41: 41 elems, type `float64`, 328 bytes
# y2         ndarray    41: 41 elems, type `float64`, 328 bytes

# %%
print(x[5:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 print(x[5:10])
#
# NameError: name 'x' is not defined

# %%
start, stop, n = 0, 20, 41
x = np.linspace(start, stop, n)
y1 = np.sin(x)
y2 = 0.3*np.random.randn(n) # Gaussian noise from numpy.random (scaled down
plt.plot(x, y1, 'b+:')
plt.plot(x, y2, 'rs-')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 start, stop, n = 0, 20, 41
# ----> 2 x = np.linspace(start, stop, n)
#       3 y1 = np.sin(x)
#       4 y2 = 0.3*np.random.randn(n) # Gaussian noise from numpy.random (scaled down
#
# NameError: name 'np' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
start, stop, n = 0, 20, 41
x = np.linspace(start, stop, n)
y1 = np.sin(x)
y2 = 0.3*np.random.randn(n) # Gaussian noise from numpy.random (scaled down
plt.plot(x, y1, 'b+:')
plt.plot(x, y2, 'rs-')

# %%
print(x[5:10])
# Out:
# [2.5 3.  3.5 4.  4.5]

# %%
print(x[0])
print(x[1])
# Out:
# 0.0
# 0.5

# %%
plt.plot(x)

# %%
plt.plot(x, 'go-')

# %%
# %who
# %whos
# Out:
# n	 np	 plt	 start	 stop	 x	 y1	 y2
# Variable   Type       Data/Info
# -------------------------------
# n          int        41
# np         module     <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# plt        module     <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# start      int        0
# stop       int        20
# x          ndarray    41: 41 elems, type `float64`, 328 bytes
# y1         ndarray    41: 41 elems, type `float64`, 328 bytes
# y2         ndarray    41: 41 elems, type `float64`, 328 bytes
